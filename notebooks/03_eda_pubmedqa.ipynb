# %% [markdown]
# # 03 — EDA: PubMedQA
#
# **Dataset:** Large-scale biomedical QA — answers derived from PubMed abstracts
# **Role:** Medical logic pre-training — ensuring the model understands clinical evidence reasoning
#
# ---
#
# ## Objectives
# 1. Load and inspect PubMedQA structure
# 2. Analyze question types and answer distributions
# 3. Study evidence passage characteristics
# 4. Assess relevance to radiology / chest findings domain

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

sns.set_theme(style="whitegrid")

DATA_DIR = Path("../data/raw/pubmedqa")
print(f"Data directory: {DATA_DIR}")
print(f"Directory exists: {DATA_DIR.exists()}")

# %%
# TODO: Load PubMedQA dataset (via HuggingFace datasets library)
# TODO: Display sample QA pairs with evidence passages
# TODO: Analyze answer type distribution
# TODO: Study evidence passage lengths and medical vocabulary
