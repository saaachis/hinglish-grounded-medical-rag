# %% [markdown]
# # 02 — EDA: MMCQSD (Multimodal Medical Code-Mixed Question Summarization Dataset)
#
# **Dataset:** 3,015 samples — medical images + Hinglish patient queries + English summaries
# **Role:** Linguistic template for realistic code-switching patterns in HMG dataset construction
#
# ---
#
# ## Objectives
# 1. Load and inspect dataset structure
# 2. Analyze Hinglish query patterns and code-mixing characteristics
# 3. Compute Code-Mixing Index (CMI) distribution
# 4. Study Hindi-English word-level switching patterns
# 5. Identify linguistic templates for synthetic Hinglish generation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

sns.set_theme(style="whitegrid")

DATA_DIR = Path("../data/raw/mmcqsd")
print(f"Data directory: {DATA_DIR}")
print(f"Directory exists: {DATA_DIR.exists()}")

# %%
# TODO: Load MMCQSD dataset
# TODO: Display sample Hinglish queries with English summaries
# TODO: Compute and visualize CMI distribution
# TODO: Analyze code-switching patterns
